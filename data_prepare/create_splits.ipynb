# %%
import os
import numpy as np
import pandas as pd
#import openslide
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score,confusion_matrix, balanced_accuracy_score
#import seaborn as sns

# %%
## read tcga data, the excel data is available at https://zenodo.org/records/11469546
train_df = pd.read_excel('tcga_processed.xlsx')
train_df
# Out:
#        patient ID        sample ID       2016_subtype 2016_grade  \
# 0    TCGA-P5-A737  TCGA-P5-A737-01  oligodendroglioma         G2
# 1    TCGA-E1-A7YI  TCGA-E1-A7YI-01        astrocytoma         G3
# 2    TCGA-R8-A73M  TCGA-R8-A73M-01  oligodendroglioma         G2
# 3    TCGA-QH-A6CV  TCGA-QH-A6CV-01        astrocytoma         G3
# 4    TCGA-TM-A7C5  TCGA-TM-A7C5-01  oligodendroglioma         G2
# ..            ...              ...                ...        ...
# 613  TCGA-06-5414  TCGA-06-5414-01       glioblastoma         G4
# 614  TCGA-DB-5273  TCGA-DB-5273-01        astrocytoma         G3
# 615  TCGA-06-0143  TCGA-06-0143-01       glioblastoma         G4
# 616  TCGA-27-1837  TCGA-27-1837-01       glioblastoma         G4
# 617  TCGA-DB-A75L  TCGA-DB-A75L-01        astrocytoma         G3
#
#        2016_molecular 2016_idh     2016_mgmt
# 0        idhmut-codel   idhmut    methylated
# 1    idhmut-non-codel   idhmut    methylated
# 2        idhmut-codel   idhmut    methylated
# 3               idhwt    idhwt  unmethylated
# 4        idhmut-codel   idhmut    methylated
# ..                ...      ...           ...
# 613             idhwt    idhwt  unmethylated
# 614  idhmut-non-codel   idhmut  unmethylated
# 615             idhwt    idhwt  unmethylated
# 616             idhwt    idhwt    methylated
# 617  idhmut-non-codel   idhmut    methylated
#
# [618 rows x 7 columns]

# %% [markdown]
# ## create train_val splits based subtype on TCGA

# %%
set(data_csv['2016_subtype'].values) # 3 subtypes
# Out:
# {'astrocytoma', 'glioblastoma', 'oligodendroglioma'}

# %%
# train
## generate training data with 5 different random seeds
## "splits" has 5 split
## each split consists of [train_slide_list,train_slide_label,val_slide_list,val_slide_label]
train_df = data_csv
random_seed = [2,3,5,7,11]
if not os.path.exists('data_split/tcga_split_5f/'):
    os.makedirs('data_split/tcga_split_5f/')
train_slide_list = train_df['patient ID'].values
train_label_list = train_df['2016_subtype'].values 
print(f"train, ast:{sum(train_label_list=='astrocytoma')}, gbm:{sum(train_label_list=='glioblastoma')}, oli:{sum(train_label_list=='oligodendroglioma')}")

#print(f'train, 0:{sum(train_label_list==0)}, 1:{sum(train_label_list==1)}, 2:{sum(train_label_list==2)}, 3:{sum(train_label_list==3)}, 4:{sum(train_label_list==4)}')
for s_idx, seed in enumerate(random_seed):
    ## begin split
    splits = []
    skf = StratifiedKFold(n_splits=5,random_state=seed,shuffle=True)
    for train_idx,val_idx in skf.split(train_slide_list,train_label_list):
        train_x = train_slide_list[train_idx].tolist()
        train_y = train_label_list[train_idx].tolist()

        val_x = train_slide_list[val_idx].tolist()
        val_y = train_label_list[val_idx].tolist()

        splits.append([train_x,train_y,val_x,val_y])
    np.save(f'data_split/tcga_split_5f/tcga_split_5f_s{s_idx}.npy', np.array(splits, dtype=object))
# Out:
# train, ast:266, gbm:196, oli:156

# %%
splits = np.load(f'data_split/tcga_split_5f/tcga_split_5f_s0.npy',allow_pickle=True)

# %%
train_slides, train_labels, val_slides, val_labels = splits[0]

# %%
train_slides
# Out:
# ['TCGA-E1-A7YI',
#  'TCGA-QH-A6CV',
#  'TCGA-TM-A7C5',
#  'TCGA-41-4097',
#  'TCGA-DU-7298',
#  'TCGA-12-0826',
#  'TCGA-06-6390',
#  'TCGA-DU-6395',
#  'TCGA-RR-A6KA',
#  'TCGA-TM-A84B',
#  'TCGA-14-0787',
#  'TCGA-DH-A66B',
#  'TCGA-HT-7687',
#  'TCGA-HT-8010',
#  'TCGA-DH-5141',
#  'TCGA-HT-8105',
#  'TCGA-HT-8018',
#  'TCGA-RY-A847',
#  'TCGA-TQ-A7RI',
#  'TCGA-S9-A6TU',
#  'TCGA-DB-A4X9',
#  'TCGA-CS-6188',
#  'TCGA-QH-A6X8',
#  'TCGA-QH-A6X3',
#  'TCGA-DB-A64R',
#  'TCGA-19-1386',
#  'TCGA-S9-A7R1',
#  'TCGA-02-0024',
#  'TCGA-FG-A6J3',
#  'TCGA-HT-7854',
#  'TCGA-06-0882',
#  'TCGA-HT-7468',
#  'TCGA-06-0139',
#  'TCGA-DB-A64P',
#  'TCGA-WY-A85D',
#  'TCGA-DU-A6S7',
#  'TCGA-12-1089',
#  'TCGA-DU-A5TP',
#  'TCGA-S9-A7QW',
#  'TCGA-12-1602',
#  'TCGA-DB-A75P',
#  'TCGA-QH-A6CU',
#  'TCGA-12-1598',
#  'TCGA-S9-A6U6',
#  'TCGA-19-5950',
#  'TCGA-TM-A84F',
#  'TCGA-27-2518',
#  'TCGA-E1-A7Z6',
#  'TCGA-06-1087',
#  'TCGA-E1-A7Z4',
#  'TCGA-DU-A6S8',
#  'TCGA-HT-7483',
#  'TCGA-RY-A845',
#  'TCGA-02-0075',
#  'TCGA-FG-A6IZ',
#  'TCGA-DU-5872',
#  'TCGA-HT-7467',
#  'TCGA-HT-8114',
#  'TCGA-S9-A6WG',
#  'TCGA-26-6173',
#  'TCGA-26-5135',
#  'TCGA-19-2624',
#  'TCGA-DH-5140',
#  'TCGA-FG-A4MX',
#  'TCGA-HT-8109',
#  'TCGA-12-0827',
#  'TCGA-06-0147',
#  'TCGA-27-1836',
#  'TCGA-FG-A87Q',
#  'TCGA-HT-7875',
#  'TCGA-S9-A6TZ',
#  'TCGA-RY-A83Z',
#  'TCGA-19-1786',
#  'TCGA-15-1444',
#  'TCGA-HT-8563',
#  'TCGA-DU-A76R',
#  'TCGA-S9-A6TS',
#  'TCGA-HT-A74K',
#  'TCGA-DB-A4XC',
#  'TCGA-S9-A7IZ',
#  'TCGA-02-0099',
#  'TCGA-12-0822',
#  'TCGA-HW-7489',
#  'TCGA-27-1831',
#  'TCGA-QH-A65Z',
#  'TCGA-DB-A75M',
#  'TCGA-R8-A6ML',
#  'TCGA-27-1838',
#  'TCGA-DH-5142',
#  'TCGA-12-1093',
#  'TCGA-HT-7620',
#  'TCGA-19-1385',
#  'TCGA-CS-5396',
#  'TCGA-HT-7482',
#  'TCGA-4W-AA9R',
#  'TCGA-HT-7473',
#  'TCGA-27-2526',
#  'TCGA-06-1084',
#  'TCGA-S9-A7IY',
#  'TCGA-02-0038',
#  'TCGA-19-5960',
#  'TCGA-TM-A7C3',
#  'TCGA-HT-A74O',
#  'TCGA-DU-A5TU',
#  'TCGA-02-0021',
#  'TCGA-DU-7302',
#  'TCGA-QH-A6XA',
#  'TCGA-06-0169',
#  'TCGA-VM-A8CE',
#  'TCGA-E1-A7YJ',
#  'TCGA-S9-A6U2',
#  'TCGA-P5-A735',
#  'TCGA-HT-7684',
#  'TCGA-12-3651',
#  'TCGA-FG-7641',
#  'TCGA-12-3648',
#  'TCGA-28-1746',
#  'TCGA-TQ-A7RS',
#  'TCGA-81-5911',
#  'TCGA-DB-A64W',
#  'TCGA-QH-A6CS',
#  'TCGA-06-0881',
#  'TCGA-HT-7902',
#  'TCGA-HT-A4DS',
#  'TCGA-DH-A7UV',
#  'TCGA-FG-7634',
#  'TCGA-E1-A7YO',
#  'TCGA-HT-A5R9',
#  'TCGA-S9-A6WH',
#  'TCGA-06-5411',
#  'TCGA-S9-A7QX',
#  'TCGA-28-1757',
#  'TCGA-S9-A7R3',
#  'TCGA-TQ-A7RU',
#  'TCGA-VM-A8C9',
#  'TCGA-E1-A7YM',
#  'TCGA-HT-7477',
#  'TCGA-14-0789',
#  'TCGA-DU-5853',
#  'TCGA-HT-8564',
#  'TCGA-HT-8106',
#  'TCGA-S9-A6U1',
#  'TCGA-HT-8104',
#  'TCGA-DU-A7TD',
#  'TCGA-06-1805',
#  'TCGA-DU-6403',
#  'TCGA-02-0115',
#  'TCGA-DU-5847',
#  'TCGA-19-A6J5',
#  'TCGA-26-1439',
#  'TCGA-19-1789',
#  'TCGA-S9-A7J3',
#  'TCGA-DH-5143',
#  'TCGA-S9-A89Z',
#  'TCGA-TM-A84I',
#  'TCGA-02-0011',
#  'TCGA-02-0037',
#  'TCGA-E1-A7YV',
#  'TCGA-HT-7609',
#  'TCGA-02-0071',
#  'TCGA-DU-5874',
#  'TCGA-QH-A6CY',
#  'TCGA-TM-A84G',
#  'TCGA-DU-6396',
#  'TCGA-HT-8111',
#  'TCGA-06-0129',
#  'TCGA-12-1088',
#  'TCGA-TQ-A7RH',
#  'TCGA-41-2572',
#  'TCGA-HT-7601',
#  'TCGA-HT-A74H',
#  'TCGA-26-5139',
#  'TCGA-28-1755',
#  'TCGA-DU-6405',
#  'TCGA-RY-A83Y',
#  'TCGA-S9-A6U0',
#  'TCGA-27-2527',
#  'TCGA-HT-A614',
#  'TCGA-S9-A7J1',
#  'TCGA-DB-5276',
#  'TCGA-12-3646',
#  'TCGA-HW-8319',
#  'TCGA-DU-6392',
#  'TCGA-QH-A65V',
#  'TCGA-06-0875',
#  'TCGA-FG-8186',
#  'TCGA-HT-7877',
#  'TCGA-DB-A64S',
#  'TCGA-P5-A72X',
#  'TCGA-HT-7680',
#  'TCGA-E1-A7YW',
#  'TCGA-HW-7487',
#  'TCGA-FG-A70Z',
#  'TCGA-DB-5280',
#  'TCGA-HT-8011',
#  'TCGA-TM-A7C4',
#  'TCGA-02-0014',
#  'TCGA-12-0670',
#  'TCGA-FG-A4MY',
#  'TCGA-CS-5390',
#  'TCGA-S9-A6WI',
#  'TCGA-P5-A780',
#  'TCGA-19-5954',
#  'TCGA-HT-7479',
#  'TCGA-P5-A77X',
#  'TCGA-DU-A7T6',
#  'TCGA-HT-7692',
#  'TCGA-HT-A5R7',
#  'TCGA-DU-7290',
#  'TCGA-FG-6689',
#  'TCGA-19-5959',
#  'TCGA-DU-A7TC',
#  'TCGA-CS-6665',
#  'TCGA-FG-8185',
#  'TCGA-28-1749',
#  'TCGA-DU-A5TR',
#  'TCGA-HT-7694',
#  'TCGA-TQ-A7RJ',
#  'TCGA-DB-A4XF',
#  'TCGA-06-5413',
#  'TCGA-CS-6668',
#  'TCGA-06-0126',
#  'TCGA-TM-A84L',
#  'TCGA-14-1823',
#  'TCGA-02-0054',
#  'TCGA-4W-AA9T',
#  'TCGA-HW-7486',
#  'TCGA-02-0003',
#  'TCGA-FG-6688',
#  'TCGA-HT-7606',
#  'TCGA-02-0052',
#  'TCGA-06-5859',
#  'TCGA-DU-7292',
#  'TCGA-KT-A7W1',
#  'TCGA-P5-A72W',
#  'TCGA-S9-A7QZ',
#  'TCGA-WY-A859',
#  'TCGA-12-0820',
#  'TCGA-HT-7604',
#  'TCGA-RY-A840',
#  'TCGA-DU-5851',
#  'TCGA-12-0821',
#  'TCGA-DU-6406',
#  'TCGA-VM-A8CB',
#  'TCGA-DU-6402',
#  'TCGA-DU-8164',
#  'TCGA-HT-7611',
#  'TCGA-S9-A6WQ',
#  'TCGA-QH-A6X4',
#  'TCGA-FG-A713',
#  'TCGA-DU-5854',
#  'TCGA-HT-7873',
#  'TCGA-HW-7491',
#  'TCGA-P5-A77W',
#  'TCGA-E1-A7YN',
#  'TCGA-DU-A5TW',
#  'TCGA-12-3644',
#  'TCGA-19-A6J4',
#  'TCGA-14-1821',
#  'TCGA-HT-7860',
#  'TCGA-E1-A7YK',
#  'TCGA-DU-A6S2',
#  'TCGA-28-1752',
#  'TCGA-19-1791',
#  'TCGA-DH-5144',
#  'TCGA-27-2528',
#  'TCGA-S9-A6U8',
#  'TCGA-VM-A8CH',
#  'TCGA-DU-7304',
#  'TCGA-02-0006',
#  'TCGA-14-1795',
#  'TCGA-VM-A8CF',
#  'TCGA-HT-7879',
#  'TCGA-TQ-A7RK',
#  'TCGA-TM-A84S',
#  'TCGA-41-3393',
#  'TCGA-19-A60I',
#  'TCGA-DH-A7UT',
#  'TCGA-TQ-A7RG',
#  'TCGA-02-0074',
#  'TCGA-06-0148',
#  'TCGA-06-0128',
#  'TCGA-S9-A6U9',
#  'TCGA-CS-6666',
#  'TCGA-06-6389',
#  'TCGA-E1-A7YL',
#  'TCGA-DU-A7T8',
#  'TCGA-06-0879',
#  'TCGA-14-0817',
#  'TCGA-KT-A74X',
#  'TCGA-HW-A5KK',
#  'TCGA-DU-6397',
#  'TCGA-4W-AA9S',
#  'TCGA-F6-A8O3',
#  'TCGA-HT-7610',
#  'TCGA-FG-A87N',
#  'TCGA-06-0124',
#  'TCGA-WY-A85A',
#  'TCGA-14-1827',
#  'TCGA-26-6174',
#  'TCGA-TM-A84R',
#  'TCGA-12-0819',
#  'TCGA-FG-A710',
#  'TCGA-HT-8110',
#  'TCGA-HW-8321',
#  'TCGA-E1-A7YH',
#  'TCGA-19-2619',
#  'TCGA-DU-8168',
#  'TCGA-14-1396',
#  'TCGA-TM-A84O',
#  'TCGA-HT-A74J',
#  'TCGA-S9-A7IS',
#  'TCGA-DU-5849',
#  'TCGA-02-0069',
#  'TCGA-TM-A84H',
#  'TCGA-TQ-A7RO',
#  'TCGA-12-3652',
#  'TCGA-F6-A8O4',
#  'TCGA-DU-6542',
#  'TCGA-HT-7858',
#  'TCGA-14-1451',
#  'TCGA-02-0058',
#  'TCGA-QH-A65S',
#  'TCGA-DU-6393',
#  'TCGA-FG-8181',
#  'TCGA-HW-A5KM',
#  'TCGA-26-A7UX',
#  'TCGA-HT-7695',
#  'TCGA-FG-5962',
#  'TCGA-RR-A6KB',
#  'TCGA-87-5896',
#  'TCGA-TM-A84Q',
#  'TCGA-HT-7605',
#  'TCGA-DU-5870',
#  'TCGA-HT-A74L',
#  'TCGA-RR-A6KC',
#  'TCGA-14-1829',
#  'TCGA-DU-7299',
#  'TCGA-DB-A64V',
#  'TCGA-HT-7681',
#  'TCGA-RY-A843',
#  'TCGA-02-0034',
#  'TCGA-QH-A86X',
#  'TCGA-27-2519',
#  'TCGA-P5-A733',
#  'TCGA-14-1453',
#  'TCGA-FG-8187',
#  'TCGA-S9-A6WD',
#  'TCGA-TQ-A7RQ',
#  'TCGA-DU-7300',
#  'TCGA-HT-7480',
#  'TCGA-TM-A84T',
#  'TCGA-12-1599',
#  'TCGA-06-0878',
#  'TCGA-DU-7011',
#  'TCGA-DU-5852',
#  'TCGA-02-0010',
#  'TCGA-27-1835',
#  'TCGA-DU-7009',
#  'TCGA-S9-A6TV',
#  'TCGA-S9-A7IQ',
#  'TCGA-26-5134',
#  'TCGA-DB-5279',
#  'TCGA-QH-A6CX',
#  'TCGA-14-0813',
#  'TCGA-14-0867',
#  'TCGA-FG-A60K',
#  'TCGA-E1-A7YE',
#  'TCGA-19-5953',
#  'TCGA-19-5955',
#  'TCGA-DU-8158',
#  'TCGA-S9-A7R8',
#  'TCGA-FN-7833',
#  'TCGA-41-3915',
#  'TCGA-VV-A86M',
#  'TCGA-HW-8320',
#  'TCGA-DU-6400',
#  'TCGA-CS-5397',
#  'TCGA-DU-7006',
#  'TCGA-P5-A731',
#  'TCGA-TQ-A7RP',
#  'TCGA-E1-A7YU',
#  'TCGA-06-5418',
#  'TCGA-19-1390',
#  'TCGA-HT-7856',
#  'TCGA-12-1600',
#  'TCGA-HT-7481',
#  'TCGA-S9-A6WO',
#  'TCGA-DU-7018',
#  'TCGA-DB-A4XB',
#  'TCGA-FG-A60L',
#  'TCGA-14-1455',
#  'TCGA-CS-4943',
#  'TCGA-06-1800',
#  'TCGA-06-5412',
#  'TCGA-S9-A7R7',
#  'TCGA-41-5651',
#  'TCGA-HT-A5RA',
#  'TCGA-12-0829',
#  'TCGA-DB-5274',
#  'TCGA-DB-A4XH',
#  'TCGA-DB-A64Q',
#  'TCGA-DH-A7UU',
#  'TCGA-FG-A60J',
#  'TCGA-RY-A83X',
#  'TCGA-TQ-A7RM',
#  'TCGA-S9-A6UB',
#  'TCGA-HT-A4DV',
#  'TCGA-27-2524',
#  'TCGA-DU-6394',
#  'TCGA-TM-A84M',
#  'TCGA-41-3392',
#  'TCGA-14-0786',
#  'TCGA-HT-7857',
#  'TCGA-S9-A6TX',
#  'TCGA-HT-7874',
#  'TCGA-TQ-A7RV',
#  'TCGA-FG-7638',
#  'TCGA-DB-5278',
#  'TCGA-19-2620',
#  'TCGA-HT-8015',
#  'TCGA-DH-A7UR',
#  'TCGA-QH-A65R',
#  'TCGA-HW-A5KL',
#  'TCGA-06-5408',
#  'TCGA-CS-6290',
#  'TCGA-CS-6670',
#  'TCGA-14-1825',
#  'TCGA-S9-A6WP',
#  'TCGA-12-3653',
#  'TCGA-26-5133',
#  'TCGA-FG-8188',
#  'TCGA-WY-A85C',
#  'TCGA-06-0122',
#  'TCGA-QH-A65X',
#  'TCGA-19-5947',
#  'TCGA-DH-A66D',
#  'TCGA-26-5132',
#  'TCGA-HT-A61B',
#  'TCGA-14-0871',
#  'TCGA-HW-8322',
#  'TCGA-DU-8167',
#  'TCGA-HT-A618',
#  'TCGA-S9-A6TW',
#  'TCGA-DB-5277',
#  'TCGA-HW-A5KJ',
#  'TCGA-DU-7306',
#  'TCGA-S9-A7IX',
#  'TCGA-CS-5394',
#  'TCGA-S9-A89V',
#  'TCGA-CS-6667',
#  'TCGA-EZ-7264',
#  'TCGA-HT-7485',
#  'TCGA-02-0007',
#  'TCGA-S9-A6WE',
#  'TCGA-QH-A6CW',
#  'TCGA-DU-7010',
#  'TCGA-DU-A7TJ',
#  'TCGA-19-2629',
#  'TCGA-S9-A7R2',
#  'TCGA-06-6388',
#  'TCGA-DH-A669',
#  'TCGA-DU-7013',
#  'TCGA-HT-7474',
#  'TCGA-27-1833',
#  'TCGA-27-1834',
#  'TCGA-FG-A4MW',
#  'TCGA-DU-7012',
#  'TCGA-TQ-A7RR',
#  'TCGA-W9-A837',
#  'TCGA-HT-A5RB',
#  'TCGA-06-0133',
#  'TCGA-HT-8013',
#  'TCGA-S9-A6WM',
#  'TCGA-DB-5281',
#  'TCGA-HT-7691',
#  'TCGA-19-1387',
#  'TCGA-CS-4942',
#  'TCGA-06-1801',
#  'TCGA-P5-A72Z',
#  'TCGA-06-5415',
#  'TCGA-CS-4941',
#  'TCGA-27-2523',
#  'TCGA-41-2575',
#  'TCGA-HT-7616',
#  'TCGA-FG-A4MU',
#  'TCGA-E1-A7YS',
#  'TCGA-06-0130',
#  'TCGA-06-5410',
#  'TCGA-DB-A4XA',
#  'TCGA-06-5414',
#  'TCGA-DB-5273',
#  'TCGA-06-0143',
#  'TCGA-27-1837']

# %%
train_labels
# Out:
# ['astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'astrocytoma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'astrocytoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'glioblastoma',
#  'oligodendroglioma',
#  'glioblastoma',
#  'astrocytoma',
#  'glioblastoma',
#  'glioblastoma']
